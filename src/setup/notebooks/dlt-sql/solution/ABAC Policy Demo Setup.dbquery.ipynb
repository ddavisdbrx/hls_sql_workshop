-- %%
CREATE TABLE IF NOT EXISTS abac_policy_demo (
  ssn STRING
)
USING DELTA;

INSERT INTO abac_policy_demo (ssn) VALUES
('123-456-7890'),
('234-567-8901'),
('345-678-9012'),
('456-789-0123'),
('567-890-1234'),
('678-901-2345'),
('789-012-3456'),
('890-123-4567'),
('901-234-5678'),
('012-345-6789');

select * from abac_policy_demo;

CREATE FUNCTION mask_ssn(ssn STRING)
RETURN '***-**-****';
